# %%
import sys
import tinygp
import jax.numpy as jnp
import numpy as np
import numpyro
import numpyro.distributions as dist
import matplotlib.pyplot as plt
import jax.numpy as jnp

from mind_the_gaps.gpmodelling import GPModelling, GPModellingComparison
from mind_the_gaps.lightcurves import GappyLightcurve
from mind_the_gaps.models.kernel_spec import (
    KernelParameterSpec,
    KernelSpec,
    KernelTermSpec,
)
from mind_the_gaps.simulator import Simulator
from scipy.stats import percentileofscore
from mind_the_gaps.models.psd_models import BendingPowerlaw, Lorentzian

# %% [markdown]
# ## Case of No period

# %% [markdown]
# # Define parameters for lightcurve simulation

# %%
times  = np.arange(0, 1000)
dt = np.diff(times)[0]

mean = 100

#A = (mean * 0.1) ** 2 # variance of the lorentzian
#Q = 80
variance_drw = (mean * 0.1) ** 2  # variance of the DRW (bending powerlaw)
w_bend = 2 * np.pi / 20 # angular frequency of the DRW or Bending Powerlaw

# define the PSD model
psd_model = BendingPowerlaw(variance_drw, w_bend)

# %% [markdown]
# # Simulate lightcurve

# %%
# create simulator object
simulator = Simulator(psd_model, times, np.ones(len(times)) * dt, mean, pdf="Gaussian", 
                     extension_factor=2)
# simulate noiseless count rates from the PSD, make the initial lightcurve 2 times as long as the original times
countrates = simulator.generate_lightcurve()
# add (Poisson) noise
noisy_countrates, dy = simulator.add_noise(countrates)

input_lc = GappyLightcurve(times, noisy_countrates, dy, exposures=dt)

fig = plt.figure()
plt.errorbar(times, noisy_countrates, yerr=dy)
plt.xlabel("Time (days)")
plt.ylabel("Rates (ct/s)")
# Out:
# /Users/connorourke/miniconda3/envs/mind_the_gaps/lib/python3.11/site-packages/stingray/utils.py:403: UserWarning: SIMON says: Stingray only uses poisson err_dist at the moment. All analysis in the light curve will assume Poisson errors. Sorry for the inconvenience.
#   warnings.warn("SIMON says: {0}".format(message), **kwargs)
# Text(0, 0.5, 'Rates (ct/s)')

# %% [markdown]
# # Define null hypothesis
#
# The kernel is defined through a [KernelSpec](../../../../mind_the_gaps/mind_the_gaps/models/kernel_spec.py) object. In order to select the celerite2 engine and use Numpyro for deriving the posteriors simply pass through a celerite2 jax `Term`  class in the `term_class` of the `KernelTermSpec` as below (In this case a celerite2 jax `RealTerm`):

# %%
# null 
null_kernel_spec = KernelSpec(
        terms=[
            KernelTermSpec(
                term_class=tinygp.kernels.quasisep.Celerite,
                parameters={
                    "a": KernelParameterSpec(
                        value=jnp.log(variance_drw),
                        prior=dist.Uniform,
                        bounds=(-10.0, 50.0),
                    ),
                    "b": KernelParameterSpec(value=-1e20, zeroed=True),
                    "c": KernelParameterSpec(
                        value=jnp.log(w_bend),
                        prior=dist.Uniform,
                        bounds=(-10.0, 10.0),
                    ),
                    "d": KernelParameterSpec(value=-1e20, zeroed=True),
                },
            )
        ],
    )

null_model = GPModelling(kernel_spec=null_kernel_spec,lightcurve=input_lc,meanmodel=None,mean_params=jnp.array([input_lc.mean]))

# %% [markdown]
# # Derive the posteriors for the null model
#
# Derive posteriors using the TinyGP engine will either use Numpyro's NUTS, or AIES MCMC routines to sample the parameters space (for AIES pass through `AIES=True`).
#
# For NUTS the `num_chains` will parallelise over the chains on threads (in this case 4 - though it will run the chains serially within a notebook. to parallelise run from a standalone script).
#
# For AIES the `num_chains` will be vectorised using JAX.
#
# `fit` tells the method to minimize the negative log likelihood with respect to parameters, and then to use those optimised parameters as a starting point (with a Gaussian distribution) for the starting points of the chains.

# %%
null_model.derive_posteriors(fit=True, max_steps=25000, num_chains=4, num_warmup=1000, converge_steps=500, progress=False,aies=False)
null_model.plot_autocorrelation()
null_model.corner_plot_samples()
# Out:
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/tinygp_engine.py:158: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/tinygp_engine.py:174: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# MCMC not converged after 500 steps.
# MCMC not converged after 1000 steps.
# MCMC not converged after 1500 steps.
# MCMC not converged after 2000 steps.
# MCMC converged after 2500 steps.

# %% [markdown]
# # Define alternative model
#
# The kernel is defined through a [KernelSpec](../../../../mind_the_gaps/mind_the_gaps/models/kernel_spec.py) object. In order to select the TinyGP engine and use Numpyro for deriving the posteriors simply pass through a TinyGP celerite `Kernel`  class in the `term_class` of the `KernelTermSpec` as below (In this case the equivalent of a combination of a `RealTerm` and `ComplexTerm`):

# %%
P = 10 # period of the QPO
w = 2 * np.pi / P
# Define starting parameters
log_variance_qpo = np.log(variance_drw)
Q = 80 # coherence
log_c = jnp.log(0.5 * w/Q)
log_d = jnp.log(w)
print(f"log variance of the QPO: {log_variance_qpo:.2f}, log_c: {log_c:.2f}, log omega: {log_d:.2f}")

bounds_qpo = dict(log_a=(-10, 50), log_c=(-10, 10), log_d=(-5, 5))
# You can also use Lorentzian from models.celerite_models (which is defined in terms of variance, Q and omega)
P = 10 # period of the QPO
w = 2 * np.pi / P
# Define starting parameters
log_variance_qpo = np.log(variance_drw)
Q = 80 # coherence
log_c = np.log(0.5 * w/Q)
log_d = np.log(w)

alt_kernel_spec = KernelSpec(
        terms=[
            KernelTermSpec(
                term_class=tinygp.kernels.quasisep.Celerite,
                parameters={
                    "a": KernelParameterSpec(
                        value=jnp.log(variance_drw),
                        prior=dist.Uniform,
                        bounds=(-1, 10.0),
                    ),
                    "b": KernelParameterSpec(value=-1e20, zeroed=True),
                    "c": KernelParameterSpec(
                        value=jnp.log(w_bend),
                        prior=dist.Uniform,
                        bounds=(-5.0, 5.0),
                    ),
                    "d": KernelParameterSpec(value=-1e20, zeroed=True),
                },
            ),
            KernelTermSpec(
                term_class=tinygp.kernels.quasisep.Celerite,
                parameters={
                    "a": KernelParameterSpec(
                        value=log_variance_qpo,
                        prior=dist.Uniform,
                        bounds=(-1, 10.0),
                    ),
                    "b": KernelParameterSpec(value=-1e20, zeroed=True),
                    "c": KernelParameterSpec(
                        value=log_c,
                        prior=dist.Uniform,
                        bounds=(-10.0, 10.0),
                    ),
                    "d": KernelParameterSpec(
                        value=log_d,
                        prior=dist.Uniform,
                        bounds=(-5.0, 5.0),
                    ),
                },
            ),
        ],
    )

alternative_model = GPModelling(kernel_spec=alt_kernel_spec,lightcurve=input_lc,meanmodel=None,mean_params=jnp.array([input_lc.mean]))
print("Deriving posteriors for alternative model")
alternative_model.derive_posteriors(fit=True, max_steps=25000, num_chains=4, num_warmup=1000, converge_steps=500, progress=False)

alternative_model.plot_autocorrelation()
alternative_model.corner_plot_samples()
# Out:
# log variance of the QPO: 4.61, log_c: -5.54, log omega: -0.46
# Deriving posteriors for alternative model
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:254: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:270: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# MCMC not converged after 500 steps.
# MCMC not converged after 1000 steps.
# MCMC not converged after 1500 steps.
# MCMC not converged after 2000 steps.
# MCMC not converged after 2500 steps.
# MCMC not converged after 3000 steps.
# MCMC not converged after 3500 steps.
# MCMC not converged after 4000 steps.
# MCMC not converged after 4500 steps.
# MCMC not converged after 5000 steps.
# MCMC not converged after 5500 steps.
# MCMC not converged after 6000 steps.
# MCMC not converged after 6500 steps.
# MCMC not converged after 7000 steps.
# MCMC not converged after 7500 steps.
# MCMC not converged after 8000 steps.
# MCMC not converged after 8500 steps.
# MCMC not converged after 9000 steps.
# MCMC not converged after 9500 steps.
# MCMC not converged after 10000 steps.
# MCMC not converged after 10500 steps.
# MCMC not converged after 11000 steps.
# MCMC not converged after 11500 steps.
# MCMC not converged after 12000 steps.
# MCMC not converged after 12500 steps.
# MCMC not converged after 13000 steps.
# MCMC not converged after 13500 steps.
# MCMC not converged after 14000 steps.
# MCMC not converged after 14500 steps.
# MCMC not converged after 15000 steps.
# MCMC not converged after 15500 steps.
# MCMC not converged after 16000 steps.
# MCMC not converged after 16500 steps.
# MCMC not converged after 17000 steps.
# MCMC not converged after 17500 steps.
# MCMC not converged after 18000 steps.
# MCMC not converged after 18500 steps.
# MCMC not converged after 19000 steps.
# MCMC not converged after 19500 steps.
# MCMC not converged after 20000 steps.
# MCMC not converged after 20500 steps.
# MCMC not converged after 21000 steps.
# MCMC not converged after 21500 steps.
# MCMC not converged after 22000 steps.
# MCMC not converged after 22500 steps.
# MCMC not converged after 23000 steps.
# MCMC not converged after 23500 steps.
# MCMC not converged after 24000 steps.
# MCMC not converged after 24500 steps.
# MCMC not converged after 25000 steps.

# %% [markdown]
# # Generate lightcurves from null hypothesis posteriors

# %%
nsims = 100 # typically 10,000
lcs = null_model.generate_from_posteriors(nsims=nsims)
print("Done!")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 nsims = 100 # typically 10,000
# ----> 2 lcs = null_model.generate_from_posteriors(nsims=nsims)
#       3 print("Done!")
#
# File ~/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/gpmodelling.py:177, in GPModelling.generate_from_posteriors(self, **engine_kwargs)
#     167 def generate_from_posteriors(
#     168     self, **engine_kwargs: Mapping[str, Any]
#     169 ) -> List[GappyLightcurve]:
#     170     """Generates lightcurves by sampling from the MCMC posteriors.
#     171
#     172     Returns
#    (...)
#     175         List containing lightcurves sampled from the MCMC posterirors.
#     176     """
# --> 177     return self.modelling_engine.generate_from_posteriors(**engine_kwargs)
#
# File ~/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/base_numpyro_engine.py:540, in BaseNumpyroGPEngine.generate_from_posteriors(self, nsims)
#     535 if nsims >= total_samples:
#     536     warnings.warn(
#     537         f"The number of simulation requested {nsims} is higher than the number of posterior samples {len(next(iter(self._mcmc_samples.values())))}, so many samples will be drawn more than once"
#     538     )
# --> 540 sampled_indices = np.random.choice(total_samples, nsims, replace=True)
#     541 sampled_params = np.column_stack(
#     542     [v[sampled_indices] for v in flat_samples.values()]
#     543 )
#     545 lightcurves = []
#
# NameError: name 'np' is not defined

# %% [markdown]
# # Fit the lightcurves with both null and alternative models

# %%
likelihoods_null = []
likelihoods_alt = []

for i, lc in enumerate(lcs):
    print("Processing lightcurve %d/%d" % (i + 1, len(lcs)), end="\r")
    
    # Run a small MCMC to make sure we find the global maximum of the likelihood
    # ideally we'd probably want to run more samples
    null_modelling = GPModelling(kernel_spec=null_kernel_spec,lightcurve=lc,meanmodel=None,mean_params=jnp.array([lc.mean]))
    null_modelling.derive_posteriors(fit=True, max_steps=500, num_chains=4, num_warmup=200, converge_steps=250, progress=False)
    likelihoods_null.append(null_modelling.max_loglikelihood)
    alternative_modelling = GPModelling(kernel_spec=alt_kernel_spec,lightcurve=lc,meanmodel=None,mean_params=jnp.array([lc.mean]))
    alternative_modelling.derive_posteriors(fit=True, max_steps=500, num_chains=4, num_warmup=200, converge_steps=250, progress=False)
    likelihoods_alt.append(alternative_modelling.max_loglikelihood)
    
                                                                              
print("\nDone!")
# Out:
# Processing lightcurve 1/100
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:254: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:270: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# MCMC not converged after 250 steps.
# MCMC not converged after 500 steps.
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:254: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:270: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# MCMC not converged after 250 steps.
# MCMC not converged after 500 steps.
# Processing lightcurve 2/100
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:254: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:270: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# MCMC not converged after 250 steps.
# MCMC not converged after 500 steps.
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:254: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:270: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# MCMC not converged after 250 steps.
# MCMC not converged after 500 steps.
# Processing lightcurve 3/100
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:254: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:270: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# MCMC not converged after 250 steps.
# MCMC not converged after 500 steps.
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:254: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:270: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# MCMC not converged after 250 steps.
# MCMC not converged after 500 steps.
# Processing lightcurve 4/100
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:254: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:270: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# MCMC not converged after 250 steps.
# MCMC not converged after 500 steps.
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:254: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:270: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# MCMC not converged after 250 steps.
# MCMC not converged after 500 steps.
# Processing lightcurve 5/100
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:254: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:270: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# MCMC not converged after 250 steps.
# MCMC not converged after 500 steps.
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:254: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:270: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# MCMC not converged after 250 steps.
# MCMC not converged after 500 steps.
# Processing lightcurve 6/100
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:254: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:270: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# MCMC not converged after 250 steps.
# MCMC not converged after 500 steps.
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:254: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:270: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# MCMC not converged after 250 steps.
# MCMC not converged after 500 steps.
# Processing lightcurve 7/100
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:254: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:270: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# MCMC not converged after 250 steps.
# MCMC not converged after 500 steps.
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:254: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:270: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# MCMC not converged after 250 steps.
# MCMC not converged after 500 steps.
# Processing lightcurve 8/100
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:254: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:270: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# MCMC not converged after 250 steps.
# MCMC not converged after 500 steps.
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:254: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:270: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# MCMC not converged after 250 steps.
# MCMC not converged after 500 steps.
# Processing lightcurve 9/100
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:254: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:270: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# MCMC not converged after 250 steps.
# MCMC not converged after 500 steps.
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:254: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:270: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# MCMC not converged after 250 steps.
# MCMC not converged after 500 steps.
# Processing lightcurve 10/100
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:254: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:270: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# MCMC not converged after 250 steps.
# MCMC not converged after 500 steps.
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:254: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:270: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# MCMC not converged after 250 steps.
# MCMC not converged after 500 steps.
# Processing lightcurve 11/100
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:254: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:270: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# MCMC not converged after 250 steps.
# MCMC not converged after 500 steps.
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:254: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:270: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# MCMC not converged after 250 steps.
# MCMC not converged after 500 steps.
# Processing lightcurve 12/100
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:254: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:270: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# MCMC not converged after 250 steps.
# MCMC not converged after 500 steps.
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:254: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:270: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# MCMC not converged after 250 steps.
# MCMC not converged after 500 steps.
# Processing lightcurve 13/100
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:254: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:270: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# MCMC not converged after 250 steps.
# MCMC not converged after 500 steps.
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:254: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:270: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# MCMC not converged after 250 steps.
# MCMC not converged after 500 steps.
# Processing lightcurve 14/100
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:254: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:270: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# MCMC not converged after 250 steps.
# MCMC not converged after 500 steps.
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:254: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:270: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# MCMC not converged after 250 steps.
# MCMC not converged after 500 steps.
# Processing lightcurve 15/100
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:254: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:270: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# MCMC not converged after 250 steps.
# MCMC not converged after 500 steps.
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:254: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:270: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# MCMC not converged after 250 steps.
# MCMC not converged after 500 steps.
# Processing lightcurve 16/100
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:254: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:270: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# MCMC not converged after 250 steps.
# MCMC not converged after 500 steps.
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:254: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:270: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# MCMC not converged after 250 steps.
# MCMC not converged after 500 steps.
# Processing lightcurve 17/100
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:254: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:270: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# MCMC not converged after 250 steps.
# MCMC not converged after 500 steps.
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:254: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:270: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# MCMC not converged after 250 steps.
# MCMC not converged after 500 steps.
# Processing lightcurve 18/100
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:254: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:270: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# MCMC not converged after 250 steps.
# MCMC converged after 500 steps.
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:254: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:270: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# MCMC not converged after 250 steps.
# MCMC not converged after 500 steps.
# Processing lightcurve 19/100
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:254: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:270: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# MCMC not converged after 250 steps.
# MCMC not converged after 500 steps.
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:254: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:270: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# MCMC not converged after 250 steps.
# MCMC not converged after 500 steps.
# Processing lightcurve 20/100
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:254: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:270: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# MCMC not converged after 250 steps.
# MCMC not converged after 500 steps.
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:254: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:270: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# MCMC not converged after 250 steps.
# MCMC not converged after 500 steps.
# Processing lightcurve 21/100
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:254: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:270: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# MCMC not converged after 250 steps.
# MCMC not converged after 500 steps.
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:254: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:270: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# MCMC not converged after 250 steps.
# MCMC not converged after 500 steps.
# Processing lightcurve 22/100
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:254: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:270: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# MCMC not converged after 250 steps.
# MCMC not converged after 500 steps.
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:254: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:270: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# MCMC not converged after 250 steps.
# MCMC not converged after 500 steps.
# Processing lightcurve 23/100
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:254: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:270: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# MCMC not converged after 250 steps.
# MCMC not converged after 500 steps.
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:254: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:270: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# MCMC not converged after 250 steps.
# MCMC not converged after 500 steps.
# Processing lightcurve 24/100
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:254: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:270: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# MCMC not converged after 250 steps.
# MCMC not converged after 500 steps.
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:254: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:270: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# MCMC not converged after 250 steps.
# MCMC not converged after 500 steps.
# Processing lightcurve 25/100
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:254: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
# ...
#   mcmc = MCMC(
# MCMC not converged after 250 steps.
# MCMC not converged after 500 steps.
# Processing lightcurve 93/100
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:254: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:270: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# MCMC not converged after 250 steps.
# MCMC not converged after 500 steps.
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:254: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:270: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# MCMC not converged after 250 steps.
# MCMC not converged after 500 steps.
# Processing lightcurve 94/100
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:254: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:270: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# MCMC not converged after 250 steps.
# MCMC not converged after 500 steps.
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:254: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:270: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# MCMC not converged after 250 steps.
# MCMC not converged after 500 steps.
# Processing lightcurve 95/100
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:254: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:270: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# MCMC not converged after 250 steps.
# MCMC converged after 500 steps.
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:254: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:270: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# MCMC not converged after 250 steps.
# MCMC not converged after 500 steps.
# Processing lightcurve 96/100
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:254: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:270: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# MCMC not converged after 250 steps.
# MCMC not converged after 500 steps.
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:254: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:270: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# MCMC not converged after 250 steps.
# MCMC not converged after 500 steps.
# Processing lightcurve 97/100
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:254: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:270: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# MCMC not converged after 250 steps.
# MCMC not converged after 500 steps.
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:254: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:270: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# MCMC not converged after 250 steps.
# MCMC not converged after 500 steps.
# Processing lightcurve 98/100
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:254: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:270: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# MCMC not converged after 250 steps.
# MCMC not converged after 500 steps.
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:254: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:270: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# MCMC not converged after 250 steps.
# MCMC not converged after 500 steps.
# Processing lightcurve 99/100
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:254: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:270: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# MCMC not converged after 250 steps.
# MCMC not converged after 500 steps.
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:254: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:270: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# MCMC not converged after 250 steps.
# MCMC not converged after 500 steps.
# Processing lightcurve 100/100
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:254: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:270: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# MCMC not converged after 250 steps.
# MCMC not converged after 500 steps.
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:254: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:270: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# MCMC not converged after 250 steps.
# MCMC not converged after 500 steps.
#
# Done!

# %% [markdown]
# # Calculate T_LRT distribution and compare with the observed value

# %%
plt.figure()
T_dist = -2 * (np.array(likelihoods_null) - np.array(likelihoods_alt))
print(T_dist)
plt.hist(T_dist, bins=10)
T_obs = -2 * (null_model.max_loglikelihood - alternative_model.max_loglikelihood)
print("Observed LRT_stat: %.3f" % T_obs)
perc = percentileofscore(T_dist, T_obs)
print("p-value: %.4f" % (1 - perc / 100))
plt.axvline(T_obs, label="%.2f%%" % perc, ls="--", color="black")

sigmas = [95, 99.7]
colors= ["red", "green"]
for i, sigma in enumerate(sigmas):
    plt.axvline(np.percentile(T_dist, sigma), ls="--", color=colors[i])
plt.legend()
#plt.axvline(np.percentile(T_dist, 99.97), color="green")
plt.xlabel("$T_\\mathrm{LRT}$")

#plt.savefig("LRT_statistic.png", dpi=100)
# Out:
# [ 4.55103692  2.8878787   2.03701241  0.61544622  0.87573736  9.95704013
#   4.77966941  5.18097565 12.50983227  1.05930122  3.32078637  0.66999895
#   8.840794    2.44017423  2.61483547  2.47509206  0.70389481  2.04725506
#   2.1637742   5.70327473  2.19683948  6.51282075  5.66152171  6.51611487
#   3.16487254  0.9560433   2.60769276  1.77935969  1.23312422  1.10366805
#   2.2721871   3.45473874  1.68506853  0.4307004   1.35675315  0.58958748
#   2.85807102  6.40352481  1.48454364  0.87511178  9.96873004  1.6569548
#   2.01335338  0.63153763  0.70166238  1.31403796  3.3809822   3.46362871
#   1.09959997  3.72463826  5.64908115  2.58431122  2.21844585  4.12008376
#   4.37618151  5.74353549  2.70389377  2.61827661  3.29146842  2.30257213
#   1.99265749  0.76647572  6.26986012  0.60191799  3.35698497  3.93187501
#   1.93861712  0.40568027  1.89786602  1.9896723   1.61641115  2.60163834
#   0.5323791   6.60828675  0.71656704  3.98644663  0.47039124  0.47370875
#   0.54011558  6.16654937  5.56568558  6.41564791  0.34986598  2.77645538
#   1.15819692  3.69375821  3.61863283  2.36089584  3.09504132  2.05495886
#   4.70157831  1.60523503  0.57752645  2.03017413  3.18702756  4.40660158
#   4.67217812  1.39654306  5.92740967  1.95730233]
# Observed LRT_stat: 9.505
# p-value: 0.0300
# Text(0.5, 0, '$T_\\mathrm{LRT}$')

# %% [markdown]
# We see the p-value to reject the null hypothesis is fairly low, indicating there is no signal in this data, as expected

# %% [markdown]
# # Case with Period

# %% [markdown]
# # Simulate lightcurve

# %%
times  = np.arange(0, 500)
dt = np.diff(times)[0]

mean = 100

P = 10 # period of the QPO
w_qpo = 2 * np.pi / P
w_bend = 2 * np.pi / 20 # angular frequency of the DRW or Bending Powerlaw
# Define starting parameters
variance_drw = (mean * 0.1) ** 2  # variance of the DRW (bending powerlaw)
variance_qpo = variance_drw # let's assume same variance for the QPO and the DRW

Q = 80 # coherence

psd_model = Lorentzian(variance_qpo, Q, w_qpo) + BendingPowerlaw(variance_drw, w_bend)

# %%
simulator = Simulator(psd_model, times, np.ones(len(times)) * dt, mean, pdf="Gaussian", max_iter=500)

rates = simulator.generate_lightcurve()
noisy_rates, dy = simulator.add_noise(rates)

input_lc = GappyLightcurve(times, noisy_rates, dy, exposures=dt)

fig = plt.figure()
plt.errorbar(times, noisy_rates, yerr=dy)
plt.xlabel("Time (days)")
plt.ylabel("Rates (ct/s)")
# Out:
# /Users/connorourke/miniconda3/envs/mind_the_gaps/lib/python3.11/site-packages/stingray/utils.py:403: UserWarning: SIMON says: Stingray only uses poisson err_dist at the moment. All analysis in the light curve will assume Poisson errors. Sorry for the inconvenience.
#   warnings.warn("SIMON says: {0}".format(message), **kwargs)
# Text(0, 0.5, 'Rates (ct/s)')

# %% [markdown]
# # Define null hypothesis

# %%
null_kernel_spec =  KernelSpec(
        terms=[
            KernelTermSpec(
                term_class=jax_terms.RealTerm,
                parameters={
                    "a": KernelParameterSpec(
                        value=np.log(variance_drw), 
                        bounds=(1, 50),
                        prior=dist.Uniform,

                    ),
                    "c": KernelParameterSpec(
                        value=np.log(w_bend), 
                        bounds=(-5, 5),
                        prior=dist.Uniform,
                    ),
                },
            )
        ],
    )
null_model =  GPModelling(kernel_spec=null_kernel_spec,lightcurve=input_lc,meanmodel="constant",fit_mean=True,mean_params=jnp.array([input_lc.mean]))
print("Deriving posteriors for null model")
null_model.derive_posteriors(fit=True, max_steps=25000, num_chains=4, num_warmup=1000, converge_steps=500, progress=False)
null_model.plot_autocorrelation()
null_model.corner_plot_samples()
# Out:
# Deriving posteriors for null model
# Negative Log Likelihood: 2218.369699767329 [101.394        4.60517019  -1.15785521]
# Negative Log Likelihood: 12959.469266602337 [100.08905497  50.           5.        ]
# Negative Log Likelihood: 2748.6936762448604 [101.25426645   9.46604992  -0.49847189]
# Negative Log Likelihood: 2118.633236452691 [101.36257054   5.69849976  -1.00954393]
# Negative Log Likelihood: 2117.048965991538 [101.35725787   5.84922417  -0.94815083]
# Negative Log Likelihood: 2116.9336181677177 [101.35691415   5.81435605  -0.93532624]
# Negative Log Likelihood: 2116.862739401178 [101.35448815   5.78358489  -0.90219455]
# Negative Log Likelihood: 2116.8439633653006 [101.34777059   5.77559397  -0.87730556]
# Negative Log Likelihood: 2116.843021488222 [101.3441781    5.77639547  -0.8766927 ]
# Negative Log Likelihood: 2116.8370544159166 [101.31143955   5.78042339  -0.87421615]
# Negative Log Likelihood: 2116.828139177265 [101.25250177   5.78369537  -0.8719261 ]
# Negative Log Likelihood: 2116.8049979637044 [101.07908575   5.78772933  -0.86823419]
# Negative Log Likelihood: 2116.7725877633757 [100.80175806   5.78778829  -0.86615031]
# Negative Log Likelihood: 2116.7437068422373 [100.52893647   5.77879416  -0.86643483]
# Negative Log Likelihood: 2116.7363108082536 [100.46800335   5.77505005  -0.87371939]
# Negative Log Likelihood: 2116.735760711191 [100.49022562   5.77368883  -0.87528698]
# Negative Log Likelihood: 2116.735743863067 [100.49899214   5.77343338  -0.87522017]
# Negative Log Likelihood: 2116.735743754997 [100.499732     5.77343409  -0.87519834]
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:218: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:231: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# MCMC not converged after 500 steps.
# MCMC not converged after 1000 steps.
# MCMC not converged after 1500 steps.
# MCMC not converged after 2000 steps.
# MCMC not converged after 2500 steps.
# MCMC converged after 3000 steps.

# %% [markdown]
# # Define alternative model

# %%
log_c = np.log(0.5 * w_qpo/Q)
log_d = np.log(w_qpo)
bounds_qpo = dict(log_a=(-10, 50), log_c=(-10, 10), log_d=(-5, 5))
# again you may use the Lorentzian from models.celerite_models

alternative_spec = KernelSpec(
        terms=[
            KernelTermSpec(
                term_class=jax_terms.ComplexTerm,
                parameters={
                    "a": KernelParameterSpec(
                        value=np.log(variance_qpo), 
                        bounds=(-10, 150),
                        prior=dist.Uniform
                    ),
                    "c": KernelParameterSpec(value=log_c, 
                                                 bounds=(-10, 50),
                                                 prior=dist.Uniform),
                    "d": KernelParameterSpec(value=log_d, 
                                                 bounds=(-10, 10),
                                                 prior=dist.Uniform),
                    "b": KernelParameterSpec(value=0.0, fixed=True),
                },
            ),
            KernelTermSpec(
                term_class=jax_terms.RealTerm,
                parameters={
                    "a": KernelParameterSpec(
                        value=np.log(variance_drw), 
                        bounds=(-10, 150),
                        prior=dist.Uniform
                    ),
                    "c": KernelParameterSpec(
                        value=np.log(w_bend), 
                        bounds=(-10, 10),
                        prior=dist.Uniform
                    ),
                },
            ),
        ],
    )
alternative_model = GPModelling(kernel_spec=alternative_spec,lightcurve=input_lc,meanmodel=None,mean_params=jnp.array([input_lc.mean]))
print("Deriving posteriors for alternative model")
alternative_model.derive_posteriors(fit=True, max_steps=25000, num_chains=4, num_warmup=1000, converge_steps=500, progress=False)

alternative_model.plot_autocorrelation()
alternative_model.corner_plot_samples()
# Out:
# Deriving posteriors for alternative model
# Negative Log Likelihood: 1990.9259125188187 [ 4.60517019 -5.53988184 -0.46470803  4.60517019 -1.15785521]
# Negative Log Likelihood: 2697.271434830964 [ 6.18439769 -7.40888476 10.         -0.51627771 -2.14490656]
# Negative Log Likelihood: 1990.4858154741512 [ 4.60530181 -5.54003762 -0.46383579  4.60474331 -1.15793748]
# Negative Log Likelihood: 1989.3803850540965 [ 4.60602777 -5.54096065 -0.45897762  4.60229508 -1.15840985]
# Negative Log Likelihood: 1989.3794086805076 [ 4.60601831 -5.54098247 -0.45907745  4.60227767 -1.15841334]
# Negative Log Likelihood: 1989.3785432503298 [ 4.60602146 -5.54105506 -0.45912741  4.60216714 -1.15843492]
# Negative Log Likelihood: 1989.3744307256486 [ 4.60606285 -5.54152341 -0.45927851  4.60142224 -1.15858019]
# Negative Log Likelihood: 1989.3656161837978 [ 4.60619067 -5.54271078 -0.45947531  4.5994995  -1.15895495]
# Negative Log Likelihood: 1989.3416324740551 [ 4.60660502 -5.54625913 -0.45980132  4.59370631 -1.16008373]
# Negative Log Likelihood: 1989.2861665128553 [ 4.6076741  -5.55502097 -0.46023611  4.57933718 -1.16288276]
# Negative Log Likelihood: 1989.1692218477947 [ 4.61012959 -5.57460331 -0.46068101  4.54714037 -1.16915289]
# Negative Log Likelihood: 1988.9851632030582 [ 4.61435828 -5.60761838 -0.46074315  4.49279757 -1.17973118]
# Negative Log Likelihood: 1988.8142897269147 [ 4.61899469 -5.64249521 -0.46003809  4.43876893 -1.19010968]
# Negative Log Likelihood: 1988.7673148661652 [ 4.62051066 -5.65317717 -0.45929098  4.42364833 -1.19295118]
# Negative Log Likelihood: 1988.7632575530063 [ 4.6201616  -5.65019356 -0.45909755  4.42903002 -1.19188392]
# Negative Log Likelihood: 1988.762679713546 [ 4.61992401 -5.64827939 -0.45906306  4.43236244 -1.19122796]
# Negative Log Likelihood: 1988.7619070641065 [ 4.61983585 -5.6474833  -0.45904957  4.43416243 -1.19085821]
# Negative Log Likelihood: 1988.7559203113449 [ 4.61968529 -5.64522579 -0.45898429  4.44276251 -1.18899064]
# Negative Log Likelihood: 1988.743063733445 [ 4.62012557 -5.64586823 -0.45889207  4.45404184 -1.18630564]
# Negative Log Likelihood: 1988.7070330544689 [ 4.62263877 -5.65680535 -0.45871956  4.4738454  -1.18095024]
# Negative Log Likelihood: 1988.621264906906 [ 4.63060484 -5.69692294 -0.45846245  4.50322744 -1.17144376]
# Negative Log Likelihood: 1988.4258212081622 [ 4.65179357 -5.80974683 -0.45816769  4.54420142 -1.15447355]
# Negative Log Likelihood: 1988.044374940353 [ 4.69705985 -6.05828143 -0.4580743   4.58622523 -1.12840576]
# Negative Log Likelihood: 1987.4366257305878 [ 4.77612501 -6.50159344 -0.45838441  4.59806489 -1.09677322]
# Negative Log Likelihood: 1987.1160288640417 [ 4.86769728 -7.02662259 -0.45783433  4.52955687 -1.07911602]
# Negative Log Likelihood: 1988.076298515013 [ 4.97717145 -7.6417417  -0.46101455  4.52120934 -1.04151097]
# Negative Log Likelihood: 1986.9199078183792 [ 4.90103673 -7.213952   -0.45880284  4.5270147  -1.06766372]
# Negative Log Likelihood: 1986.9180570691158 [ 4.90765646 -7.25121246 -0.45891538  4.52616749 -1.06546656]
# Negative Log Likelihood: 1986.9179285179964 [ 4.90687572 -7.24677848 -0.45889126  4.52643362 -1.06569128]
# Negative Log Likelihood: 1986.9179184308398 [ 4.90714581 -7.24825825 -0.45888945  4.52656262 -1.06556804]
# Negative Log Likelihood: 1986.9178887163444 [ 4.90801922 -7.25299141 -0.45888641  4.52696168 -1.06518539]
# Negative Log Likelihood: 1986.91782534693 [ 4.90870122 -7.2564878  -0.4588846   4.52726799 -1.06493087]
# Negative Log Likelihood: 1986.9173609247473 [ 4.91203255 -7.27246864 -0.45887673  4.52867583 -1.06394647]
# Negative Log Likelihood: 1986.916368555104 [ 4.91700088 -7.29398026 -0.45886661  4.5305501  -1.06303578]
# Negative Log Likelihood: 1986.913634410829 [ 4.92716602 -7.33241255 -0.45885032  4.53392469 -1.06249019]
# Negative Log Likelihood: 1986.907217149861 [ 4.9457316  -7.39083228 -0.45883053  4.53924386 -1.06423788]
# Negative Log Likelihood: 1986.8932133699552 [ 4.97878366 -7.47107461 -0.45881237  4.54731388 -1.07279936]
# Negative Log Likelihood: 1986.8702105920086 [ 5.02606351 -7.54903975 -0.45881795  4.55426226 -1.09405011]
# Negative Log Likelihood: 1988.3694991732702 [ 4.9851068  -6.81274915 -0.45879598  4.78283912 -1.15549833]
# Negative Log Likelihood: 1986.8691949528588 [ 5.02502477 -7.53036606 -0.4588174   4.56005939 -1.09560855]
# Negative Log Likelihood: 2235.2014031079825 [ 4.43465995  0.42077877 -0.39352152  3.88159472 -2.47020959]
# Negative Log Likelihood: 1986.870396811833 [ 5.02404681 -7.51719473 -0.45870923  4.55893549 -1.09788562]
# Negative Log Likelihood: 1986.8690268058824 [ 5.02477201 -7.52696179 -0.45878944  4.55976891 -1.09619708]
# Negative Log Likelihood: 1986.8458597723525 [ 5.06008329 -7.5266649  -0.45882318  4.55975957 -1.12588932]
# Negative Log Likelihood: 1986.8334277932338 [ 5.0624696  -7.44024899 -0.45886674  4.55347721 -1.14776108]
# Negative Log Likelihood: 1986.831308992688 [ 5.04947293 -7.38009529 -0.45889121  4.54831283 -1.1508274 ]
# Negative Log Likelihood: 1986.8311085762202 [ 5.04450237 -7.36952971 -0.45889793  4.54688939 -1.14915287]
# Negative Log Likelihood: 1986.8309952303566 [ 5.04200034 -7.36538283 -0.45890072  4.54628473 -1.14793078]
# Negative Log Likelihood: 1986.8306783338342 [ 5.03840178 -7.35906485 -0.45890514  4.54531872 -1.14594911]
# Negative Log Likelihood: 1986.829742752911 [ 5.03285116 -7.34777884 -0.45891379  4.54345576 -1.14229751]
# Negative Log Likelihood: 1986.8274199256207 [ 5.02691328 -7.33152774 -0.4589277   4.54044941 -1.13649434]
# Negative Log Likelihood: 1986.821569105717 [ 5.02437733 -7.30988627 -0.4589492   4.53558506 -1.12680302]
# Negative Log Likelihood: 1986.8081796664521 [ 5.03793091 -7.28908549 -0.45897998  4.52824156 -1.11236092]
# Negative Log Likelihood: 1986.7843917217908 [ 5.08687734 -7.26712833 -0.45892045  4.51693868 -1.0963343 ]
# Negative Log Likelihood: 1987.145799288124 [ 5.43743699 -7.68271905 -0.46038599  4.52194208 -1.02556839]
# Negative Log Likelihood: 1986.774227609972 [ 5.13672709 -7.32622553 -0.45912885  4.51765017 -1.08627135]
# Negative Log Likelihood: 1986.745671840201 [ 5.22002854 -7.36638413 -0.45903256  4.51533665 -1.0866499 ]
# Negative Log Likelihood: 1986.719817765898 [ 5.3456139  -7.48290367 -0.45892941  4.52297575 -1.10285568]
# Negative Log Likelihood: 1986.7170118185509 [ 5.38178894 -7.54482534 -0.45891312  4.52928651 -1.10914817]
# Negative Log Likelihood: 1986.7173580456583 [ 5.38774877 -7.53808609 -0.45894474  4.52946443 -1.11601649]
# Negative Log Likelihood: 1986.7169793184978 [ 5.38313744 -7.54330048 -0.45892027  4.52932677 -1.11070223]
# Negative Log Likelihood: 1986.716915946055 [ 5.38497597 -7.55266283 -0.45892277  4.53043724 -1.11092596]
# Negative Log Likelihood: 1986.7169135217014 [ 5.38461477 -7.55346859 -0.45892387  4.53056855 -1.11094067]
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:218: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:231: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# MCMC not converged after 500 steps.
# MCMC not converged after 1000 steps.
# MCMC not converged after 1500 steps.
# MCMC not converged after 2000 steps.

# %% [markdown]
# # Generate lightcurves with null hypothesis posteriors

# %%
nsims = 100 # typically 10,000
lcs = null_model.generate_from_posteriors(nsims=nsims)
print("Done!")
# Out:
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:380: UserWarning: The number of simulation requested 100 is higher than the number of posterior samples 4, so many samples will be drawn more than once
#   warnings.warn(
# /Users/connorourke/miniconda3/envs/mind_the_gaps/lib/python3.11/site-packages/stingray/utils.py:403: UserWarning: SIMON says: Stingray only uses poisson err_dist at the moment. All analysis in the light curve will assume Poisson errors. Sorry for the inconvenience.
#   warnings.warn("SIMON says: {0}".format(message), **kwargs)
# Done!

# %% [markdown]
# # Fit the lightcurves with both null and alternative models

# %%
likelihoods_null = []
likelihoods_alt = []

for i, lc in enumerate(lcs):
    print("Processing lightcurve %d/%d" % (i + 1, len(lcs)), end="\r")
    
    # Run a small MCMC to make sure we find the global maximum of the likelihood
    # ideally we'd probably want to run more samples
    null_modelling = GPModelling(kernel_spec=null_kernel_spec,lightcurve=lc,meanmodel=None,mean_params=jnp.array([lc.mean]))
    null_modelling.derive_posteriors(fit=True, max_steps=500, num_chains=4, num_warmup=200, converge_steps=250, progress=False)
    likelihoods_null.append(null_modelling.max_loglikelihood)
    alternative_modelling = GPModelling(kernel_spec=alternative_spec,lightcurve=lc,meanmodel=None,mean_params=jnp.array([lc.mean]))
    alternative_modelling.derive_posteriors(fit=True, max_steps=500, num_chains=4, num_warmup=200, converge_steps=250, progress=False)
    likelihoods_alt.append(alternative_modelling.max_loglikelihood)
    
                                                                              
print("\nDone!")
# Out:
# Processing lightcurve 1/100
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:252: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# /Users/connorourke/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite2_engine.py:268: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# MCMC not converged after 250 steps.
# MCMC not converged after 500 steps.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 12
#      10 null_modelling.derive_posteriors(fit=True, max_steps=500, num_chains=4, num_warmup=200, converge_steps=250, progress=False)
#      11 likelihoods_null.append(null_modelling.max_loglikelihood)
# ---> 12 alternative_modelling = GPModelling(kernel_spec=alternative_spec,lightcurve=lc,meanmodel=None,mean_params=jnp.array([lc.mean]))
#      13 alternative_modelling.derive_posteriors(fit=True, max_steps=500, num_chains=4, num_warmup=200, converge_steps=250, progress=False)
#      14 likelihoods_alt.append(alternative_modelling.max_loglikelihood)
#
# NameError: name 'alternative_spec' is not defined

# %% [markdown]
# # Calculate T_LRT distribution and compare with the observed value

# %%
plt.figure()
T_dist = -2 * (np.array(likelihoods_null) - np.array(likelihoods_alt))
print(T_dist)
plt.hist(T_dist, bins=10)
T_obs = -2 * (null_model.max_loglikelihood - alternative_model.max_loglikelihood)
print("Observed LRT_stat: %.3f" % T_obs)
perc = percentileofscore(T_dist, T_obs)
print("p-value: %.4f" % (1 - perc / 100))
plt.axvline(T_obs, label="%.2f%%" % perc, ls="--", color="black")

sigmas = [95, 99.7]
colors= ["red", "green"]
for i, sigma in enumerate(sigmas):
    plt.axvline(np.percentile(T_dist, sigma), ls="--", color=colors[i])
plt.legend()
#plt.axvline(np.percentile(T_dist, 99.97), color="green")
plt.xlabel("$T_\\mathrm{LRT}$")

#plt.savefig("LRT_statistic.png", dpi=100)
# Out:
# [ 1.68065491e+00  1.02494290e-02  7.06869544e-01  3.16122410e+00
#   3.38845823e-01  1.13425915e+00  6.27850974e+00  4.01441207e+00
#   2.03671168e-01  1.44597884e+00  3.80823217e-01  4.71613515e-02
#   4.00968510e-01  2.19629795e+00  3.85656827e-01  1.17539576e+00
#   1.81954479e+00  1.34639595e-01  6.04698424e-01 -5.01966756e-05
#   4.43452059e-01  3.16550680e-01  6.98149128e-01  5.71916629e+00
#   8.86790277e-02  1.67076861e+00  6.35883517e-01  3.64615121e+00
#   3.49963092e+00  4.69329995e-01  1.13339875e+00  3.70629005e-01
#   1.87024579e-01  3.38726373e-01  2.95806932e-01 -2.18857075e-04
#   1.23194306e+00  1.83324762e+00  7.96592567e-03  3.28052325e+00
#   2.70002052e+00  2.21927802e-01 -1.10974197e-02  3.51402031e+00
#   5.00162830e-01  3.98623558e-02  1.77766562e+00  2.91268356e+00
#   2.95706007e+00  5.66157824e-01  6.98826146e-01  3.64381875e-01
#   2.72161688e+00  2.69146462e+00  1.79314678e+00  5.20640222e-01
#   3.12763260e-01  1.86691813e-01  3.48700410e-01  1.16007036e+00
#  -4.49575496e-03  6.08939278e-01  3.55384796e-04  2.47255037e+00
#   2.00665689e+00  4.71525531e-01  1.97271070e-01  1.23501908e+00
#   1.04597441e+00  6.20633380e-01  3.33758105e-01  2.60254937e+00
#   6.69512856e-01  5.93238056e+00  3.51459969e+00  3.41010665e-01
#   1.43463218e-01  1.16140011e+00  4.93958582e-01  4.60585728e-01
#  -3.56909045e-03  3.10420702e-01  5.90543147e-04  1.56433789e-01
#   1.84731177e+00  5.31684710e-03  1.33741244e+00  7.62876443e-01
#   5.26358486e+00  9.70982527e-01  2.44859965e+00  2.43477231e-02
#   9.42518795e-01  7.05767707e-02  2.79843757e-03  3.37597925e-01
#   2.04537028e-01  3.98136671e+00  2.34727719e+00  6.88606435e-02]
# Observed LRT_stat: 48.415
# p-value: 0.0000
# Text(0.5, 0, '$T_\\mathrm{LRT}$')
