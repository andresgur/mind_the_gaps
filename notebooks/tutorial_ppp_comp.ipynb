# %%
from mind_the_gaps.lightcurves import GappyLightcurve
from mind_the_gaps.gpmodelling import GPModelling, GPModellingComparison
from mind_the_gaps.models.psd_models import BendingPowerlaw, Lorentzian, SHO, Matern32, Jitter
from mind_the_gaps.models import Lorentzian as Lor
from mind_the_gaps.models.celerite.celerite_models import DampedRandomWalk
from mind_the_gaps.simulator import Simulator
import numpy as np
import matplotlib.pyplot as plt
import celerite, corner
from scipy.stats import percentileofscore
from mind_the_gaps.models.kernel_spec import (
    KernelParameterSpec,
    KernelSpec,
    KernelTermSpec,
)

cpus = 10 # set the number of cores for parallelization
np.random.seed(10)

# %% [markdown]
# ## Case of No period

# %% [markdown]
# # Define parameters for lightcurve simulation

# %%
times  = np.arange(0, 1000)
dt = np.diff(times)[0]

mean = 100

#A = (mean * 0.1) ** 2 # variance of the lorentzian
#Q = 80
variance_drw = (mean * 0.1) ** 2  # variance of the DRW (bending powerlaw)
w_bend = 2 * np.pi / 20 # angular frequency of the DRW or Bending Powerlaw

# define the PSD model
psd_model = BendingPowerlaw(variance_drw, w_bend)

# %% [markdown]
# # Simulate lightcurve

# %%
# create simulator object
simulator = Simulator(psd_model, times, np.ones(len(times)) * dt, mean, pdf="Gaussian", 
                     extension_factor=2)
# simulate noiseless count rates from the PSD, make the initial lightcurve 2 times as long as the original times
countrates = simulator.generate_lightcurve()
# add (Poisson) noise
noisy_countrates, dy = simulator.add_noise(countrates)

input_lc = GappyLightcurve(times, noisy_countrates, dy, exposures=dt)

fig = plt.figure()
plt.errorbar(times, noisy_countrates, yerr=dy)
plt.xlabel("Time (days)")
plt.ylabel("Rates (ct/s)")
# Out:
# /Users/connorourke/miniconda3/envs/mind_the_gaps/lib/python3.11/site-packages/stingray/utils.py:403: UserWarning: SIMON says: Stingray only uses poisson err_dist at the moment. All analysis in the light curve will assume Poisson errors. Sorry for the inconvenience.
#   warnings.warn("SIMON says: {0}".format(message), **kwargs)
# Text(0, 0.5, 'Rates (ct/s)')

# %% [markdown]
# # Define null and alternative hypothesis

# %%
# null 
bounds_drw = dict(log_a=(-10, 50), log_c=(-10, 10))
# you can use RealTerm from celerite or DampedRandomWalk from models.celerite_models
#null_kernel = celerite.terms.RealTerm(log_a=np.log(variance_drw), log_c=np.log(w_bend), bounds=bounds_drw)
null_spec =  KernelSpec(
        terms=[
            KernelTermSpec(
                term_class=celerite.terms.RealTerm,
                parameters={
                    "log_a": KernelParameterSpec(
                        value=np.log(variance_drw), bounds=(-10, 50)
                    ),
                    "log_c": KernelParameterSpec(
                        value=np.log(w_bend), bounds=(-10, 10)
                    ),
                },
            )
        ],
    )

P = 10 # period of the QPO
w = 2 * np.pi / P
# Define starting parameters
log_variance_qpo = np.log(variance_drw)
Q = 80 # coherence
log_c = np.log(0.5 * w/Q)
log_d = np.log(w)

alternative_spec = KernelSpec(
        terms=[
            KernelTermSpec(
                term_class=celerite.terms.ComplexTerm,
                parameters={
                    "log_a": KernelParameterSpec(
                        value=log_variance_qpo, bounds=(-10, 50)
                    ),
                    "log_c": KernelParameterSpec(value=log_c, bounds=(-10, 10)),
                    "log_d": KernelParameterSpec(value=log_d, bounds=(-5, 5)),
                },
            ),
            KernelTermSpec(
                term_class=celerite.terms.RealTerm,
                parameters={
                    "log_a": KernelParameterSpec(
                        value=np.log(variance_drw), bounds=(-10, 50)
                    ),
                    "log_c": KernelParameterSpec(
                        value=np.log(w_bend), bounds=(-10, 10)
                    ),
                },
            ),
        ],
    )

# %% [markdown]
# # Set up GP Model Comparison

# %%
comparison_kwargs = {
        "null_kwargs": {
            "fit_mean": True,
            "cpus": 10,
        },
        "alt_kwargs": {
            "fit_mean": True,
            "cpus": 10,
        },
    }
gp_model_comp = GPModellingComparison(
        null_kernel_spec=null_spec,
        alt_kernel_spec=alternative_spec,
        lightcurve=input_lc,
        **comparison_kwargs,
    )

# %% [markdown]
# # Derive posteriors for both models lightcurves from null hypothesis posteriors

# %%
gp_model_comp.derive_posteriors(fit=True, max_steps=50000, cores=cpus)
# Out:
#  16%|█▌        | 8000/50000 [00:22<02:00, 349.46it/s]
# Convergence reached after 8000 samples!
#  52%|█████▏    | 26000/50000 [01:43<01:35, 251.45it/s]
# Convergence reached after 26000 samples!

# %%
gp_model_comp.null_model.plot_autocorrelation()
gp_model_comp.null_model.corner_plot_samples()

# %%
gp_model_comp.alt_model.plot_autocorrelation()
gp_model_comp.alt_model.corner_plot_samples()

# %% [markdown]
# # Generate lightcurves, and fit with both null and alternative models

# %%
gp_model_comp.process_lightcurves(nsims=100, fit=True, max_steps=1000, cores=cpus)
# Out:
# /Users/connorourke/miniconda3/envs/mind_the_gaps/lib/python3.11/site-packages/stingray/utils.py:403: UserWarning: SIMON says: Stingray only uses poisson err_dist at the moment. All analysis in the light curve will assume Poisson errors. Sorry for the inconvenience.
#   warnings.warn("SIMON says: {0}".format(message), **kwargs)
# /Users/connorourke/miniconda3/envs/mind_the_gaps/lib/python3.11/site-packages/stingray/utils.py:403: UserWarning: SIMON says: Stingray only uses poisson err_dist at the moment. All analysis in the light curve will assume Poisson errors. Sorry for the inconvenience.
#   warnings.warn("SIMON says: {0}".format(message), **kwargs)
# /Users/connorourke/miniconda3/envs/mind_the_gaps/lib/python3.11/site-packages/stingray/utils.py:403: UserWarning: SIMON says: Stingray only uses poisson err_dist at the moment. All analysis in the light curve will assume Poisson errors. Sorry for the inconvenience.
#   warnings.warn("SIMON says: {0}".format(message), **kwargs)
# /Users/connorourke/miniconda3/envs/mind_the_gaps/lib/python3.11/site-packages/stingray/utils.py:403: UserWarning: SIMON says: Stingray only uses poisson err_dist at the moment. All analysis in the light curve will assume Poisson errors. Sorry for the inconvenience.
#   warnings.warn("SIMON says: {0}".format(message), **kwargs)
# /Users/connorourke/miniconda3/envs/mind_the_gaps/lib/python3.11/site-packages/stingray/utils.py:403: UserWarning: SIMON says: Stingray only uses poisson err_dist at the moment. All analysis in the light curve will assume Poisson errors. Sorry for the inconvenience.
#   warnings.warn("SIMON says: {0}".format(message), **kwargs)
# /Users/connorourke/miniconda3/envs/mind_the_gaps/lib/python3.11/site-packages/stingray/utils.py:403: UserWarning: SIMON says: Stingray only uses poisson err_dist at the moment. All analysis in the light curve will assume Poisson errors. Sorry for the inconvenience.
#   warnings.warn("SIMON says: {0}".format(message), **kwargs)
# /Users/connorourke/miniconda3/envs/mind_the_gaps/lib/python3.11/site-packages/stingray/utils.py:403: UserWarning: SIMON says: Stingray only uses poisson err_dist at the moment. All analysis in the light curve will assume Poisson errors. Sorry for the inconvenience.
#   warnings.warn("SIMON says: {0}".format(message), **kwargs)
# /Users/connorourke/miniconda3/envs/mind_the_gaps/lib/python3.11/site-packages/stingray/utils.py:403: UserWarning: SIMON says: Stingray only uses poisson err_dist at the moment. All analysis in the light curve will assume Poisson errors. Sorry for the inconvenience.
#   warnings.warn("SIMON says: {0}".format(message), **kwargs)
# /Users/connorourke/miniconda3/envs/mind_the_gaps/lib/python3.11/site-packages/stingray/utils.py:403: UserWarning: SIMON says: Stingray only uses poisson err_dist at the moment. All analysis in the light curve will assume Poisson errors. Sorry for the inconvenience.
#   warnings.warn("SIMON says: {0}".format(message), **kwargs)
# /Users/connorourke/miniconda3/envs/mind_the_gaps/lib/python3.11/site-packages/stingray/utils.py:403: UserWarning: SIMON says: Stingray only uses poisson err_dist at the moment. All analysis in the light curve will assume Poisson errors. Sorry for the inconvenience.
#   warnings.warn("SIMON says: {0}".format(message), **kwargs)
# /Users/connorourke/miniconda3/envs/mind_the_gaps/lib/python3.11/site-packages/stingray/utils.py:403: UserWarning: SIMON says: Stingray only uses poisson err_dist at the moment. All analysis in the light curve will assume Poisson errors. Sorry for the inconvenience.
#   warnings.warn("SIMON says: {0}".format(message), **kwargs)
# /Users/connorourke/miniconda3/envs/mind_the_gaps/lib/python3.11/site-packages/stingray/utils.py:403: UserWarning: SIMON says: Stingray only uses poisson err_dist at the moment. All analysis in the light curve will assume Poisson errors. Sorry for the inconvenience.
#   warnings.warn("SIMON says: {0}".format(message), **kwargs)
# /Users/connorourke/miniconda3/envs/mind_the_gaps/lib/python3.11/site-packages/stingray/utils.py:403: UserWarning: SIMON says: Stingray only uses poisson err_dist at the moment. All analysis in the light curve will assume Poisson errors. Sorry for the inconvenience.
#   warnings.warn("SIMON says: {0}".format(message), **kwargs)
# /Users/connorourke/miniconda3/envs/mind_the_gaps/lib/python3.11/site-packages/stingray/utils.py:403: UserWarning: SIMON says: Stingray only uses poisson err_dist at the moment. All analysis in the light curve will assume Poisson errors. Sorry for the inconvenience.
#   warnings.warn("SIMON says: {0}".format(message), **kwargs)
# /Users/connorourke/miniconda3/envs/mind_the_gaps/lib/python3.11/site-packages/stingray/utils.py:403: UserWarning: SIMON says: Stingray only uses poisson err_dist at the moment. All analysis in the light curve will assume Poisson errors. Sorry for the inconvenience.
#   warnings.warn("SIMON says: {0}".format(message), **kwargs)
# /Users/connorourke/miniconda3/envs/mind_the_gaps/lib/python3.11/site-packages/stingray/utils.py:403: UserWarning: SIMON says: Stingray only uses poisson err_dist at the moment. All analysis in the light curve will assume Poisson errors. Sorry for the inconvenience.
#   warnings.warn("SIMON says: {0}".format(message), **kwargs)
# Processing lightcurve 1/100
# 100%|██████████| 1000/1000 [00:02<00:00, 345.45it/s]
# 100%|██████████| 1000/1000 [00:03<00:00, 289.04it/s]
# Processing lightcurve 2/100
# 100%|██████████| 1000/1000 [00:02<00:00, 367.04it/s]
# 100%|██████████| 1000/1000 [00:03<00:00, 280.46it/s]
# Processing lightcurve 3/100
# 100%|██████████| 1000/1000 [00:02<00:00, 371.53it/s]
# 100%|██████████| 1000/1000 [00:03<00:00, 305.17it/s]
# Processing lightcurve 4/100
# 100%|██████████| 1000/1000 [00:02<00:00, 395.11it/s]
# 100%|██████████| 1000/1000 [00:03<00:00, 312.04it/s]
# Processing lightcurve 5/100
# 100%|██████████| 1000/1000 [00:02<00:00, 367.49it/s]
# 100%|██████████| 1000/1000 [00:03<00:00, 286.14it/s]
# Processing lightcurve 6/100
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 gp_model_comp.process_lightcurves(nsims=100, fit=True, max_steps=1000, cores=cpus)
#
# File ~/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/gpmodelling.py:337, in GPModellingComparison.process_lightcurves(self, nsims, **engine_kwargs)
#     330 print("Processing lightcurve %d/%d" % (i + 1, len(lcs)), end="\r")
#     332 null_modelling = GPModelling(
#     333     kernel_spec=self.null_kernel_spec,
#     334     lightcurve=lc,
#     335     **self.null_modelling_kwargs,
#     336 )
# --> 337 null_modelling.derive_posteriors(**engine_kwargs)
#     338 self.likelihoods_null.append(null_modelling.max_loglikelihood)
#     340 alternative_modelling = GPModelling(
#     341     kernel_spec=self.alt_kernel_spec,
#     342     lightcurve=lc,
#     343     **self.alt_modelling_kwargs,
#     344 )
#
# File ~/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/gpmodelling.py:152, in GPModelling.derive_posteriors(self, **engine_kwargs)
#     150 """Vaidate the engine kwargs and derive the posteriors."""
#     151 self.modelling_engine.validate_kwargs(engine_kwargs)
# --> 152 self.modelling_engine.derive_posteriors(**engine_kwargs)
#
# File ~/bin/src/TEMP_MTG/mind_the_gaps/mind_the_gaps/engines/celerite_engine.py:174, in CeleriteGPEngine.derive_posteriors(self, initial_chain_params, fit, converge, max_steps, walkers, cores, progress)
#     170 self.converged = False
#     171 sampler = emcee.EnsembleSampler(
#     172     walkers, self._ndim, self._log_probability, pool=pool
#     173 )
# --> 174 for sample in sampler.sample(
#     175     initial_chain_params, iterations=max_steps, progress=progress
#     176 ):
#     177     # Only check convergence every 100 steps
#     178     if sampler.iteration % every_samples:
#     179         continue
#
# File ~/miniconda3/envs/mind_the_gaps/lib/python3.11/site-packages/emcee/ensemble.py:344, in EnsembleSampler.sample(self, initial_state, log_prob0, rstate0, blobs0, iterations, tune, skip_initial_state_check, thin_by, thin, store, progress, progress_kwargs)
#     342     state.blobs = blobs0
#     343 if state.log_prob is None:
# --> 344     state.log_prob, state.blobs = self.compute_log_prob(state.coords)
#     345 if np.shape(state.log_prob) != (self.nwalkers,):
#     346     raise ValueError("incompatible input dimensions")
#
# File ~/miniconda3/envs/mind_the_gaps/lib/python3.11/site-packages/emcee/ensemble.py:489, in EnsembleSampler.compute_log_prob(self, coords)
#     487     else:
#     488         map_func = map
# --> 489     results = list(map_func(self.log_prob_fn, p))
#     491 try:
#     492     log_prob = np.array([float(l[0]) for l in results])
#
# File ~/miniconda3/envs/mind_the_gaps/lib/python3.11/multiprocessing/pool.py:367, in Pool.map(self, func, iterable, chunksize)
#     362 def map(self, func, iterable, chunksize=None):
#     363     '''
#     364     Apply `func` to each element in `iterable`, collecting the results
#     365     in a list that is returned.
#     366     '''
# --> 367     return self._map_async(func, iterable, mapstar, chunksize).get()
#
# File ~/miniconda3/envs/mind_the_gaps/lib/python3.11/multiprocessing/pool.py:768, in ApplyResult.get(self, timeout)
#     767 def get(self, timeout=None):
# --> 768     self.wait(timeout)
#     769     if not self.ready():
#     770         raise TimeoutError
#
# File ~/miniconda3/envs/mind_the_gaps/lib/python3.11/multiprocessing/pool.py:765, in ApplyResult.wait(self, timeout)
#     764 def wait(self, timeout=None):
# --> 765     self._event.wait(timeout)
#
# File ~/miniconda3/envs/mind_the_gaps/lib/python3.11/threading.py:629, in Event.wait(self, timeout)
#     627 signaled = self._flag
#     628 if not signaled:
# --> 629     signaled = self._cond.wait(timeout)
#     630 return signaled
#
# File ~/miniconda3/envs/mind_the_gaps/lib/python3.11/threading.py:327, in Condition.wait(self, timeout)
#     325 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     326     if timeout is None:
# --> 327         waiter.acquire()
#     328         gotit = True
#     329     else:
#
# KeyboardInterrupt:

# %% [markdown]
# # Perform Likelihood Ratio Test

# %%
gp_model_comp.likelihood_ratio_test(path="LRT_no_period.png")

# %% [markdown]
# We see the p-value to reject the null hypothesis is fairly low, indicating there is no signal in this data, as expected

# %% [markdown]
# # Case with Period

# %% [markdown]
# # Simulate lightcurve

# %%
times  = np.arange(0, 500)
dt = np.diff(times)[0]

mean = 100

P = 10 # period of the QPO
w_qpo = 2 * np.pi / P
w_bend = 2 * np.pi / 20 # angular frequency of the DRW or Bending Powerlaw
# Define starting parameters
variance_drw = (mean * 0.1) ** 2  # variance of the DRW (bending powerlaw)
variance_qpo = variance_drw # let's assume same variance for the QPO and the DRW

Q = 80 # coherence

psd_model = Lorentzian(variance_qpo, Q, w_qpo) + BendingPowerlaw(variance_drw, w_bend)

# %%
simulator = Simulator(psd_model, times, np.ones(len(times)) * dt, mean, pdf="Gaussian", max_iter=500)

rates = simulator.generate_lightcurve()
noisy_rates, dy = simulator.add_noise(rates)

input_lc = GappyLightcurve(times, noisy_rates, dy, exposures=dt)

fig = plt.figure()
plt.errorbar(times, noisy_rates, yerr=dy)
plt.xlabel("Time (days)")
plt.ylabel("Rates (ct/s)")
# Out:
# Text(0, 0.5, 'Rates (ct/s)')

# %% [markdown]
# # Define null hypothesis

# %%
null_kernel_spec =  KernelSpec(
        terms=[
            KernelTermSpec(
                term_class=celerite.terms.RealTerm,
                parameters={
                    "log_a": KernelParameterSpec(
                        value=np.log(variance_drw), bounds=(-10, 50)
                    ),
                    "log_c": KernelParameterSpec(
                        value=np.log(w_bend), bounds=(-10, 10)
                    ),
                },
            )
        ],
    )

# %% [markdown]
# # Define alternative model

# %%
log_c = np.log(0.5 * w_qpo/Q)
log_d = np.log(w_qpo)
bounds_qpo = dict(log_a=(-10, 50), log_c=(-10, 10), log_d=(-5, 5))
# again you may use the Lorentzian from models.celerite_models

alternative_spec = KernelSpec(
        terms=[
            KernelTermSpec(
                term_class=celerite.terms.ComplexTerm,
                parameters={
                    "log_a": KernelParameterSpec(
                        value=log_variance_qpo, bounds=(-10, 50)
                    ),
                    "log_c": KernelParameterSpec(value=log_c, bounds=(-10, 10)),
                    "log_d": KernelParameterSpec(value=log_d, bounds=(-5, 5)),
                },
            ),
            KernelTermSpec(
                term_class=celerite.terms.RealTerm,
                parameters={
                    "log_a": KernelParameterSpec(
                        value=np.log(variance_drw), bounds=(-10, 50)
                    ),
                    "log_c": KernelParameterSpec(
                        value=np.log(w_bend), bounds=(-10, 10)
                    ),
                },
            ),
        ],
    )

# %% [markdown]
# # Set up GP Model Comparison

# %%
comparison_kwargs = {
        "null_kwargs": {
            "fit_mean": True,
            "cpus": 10,
        },
        "alt_kwargs": {
            "fit_mean": True,
            "cpus": 10,
        },
    }
gp_model_comp = GPModellingComparison(
        null_kernel_spec=null_spec,
        alt_kernel_spec=alternative_spec,
        lightcurve=input_lc,
        **comparison_kwargs,
    )

# %% [markdown]
# # Derive Posteriors for null and alternative models

# %%
gp_model_comp.derive_posteriors(fit=True, max_steps=50000, cores=cpus)
# Out:
#  20%|██        | 10000/50000 [00:23<01:34, 423.57it/s]
# Convergence reached after 10000 samples!
#  25%|██▌       | 12500/50000 [00:41<02:04, 301.65it/s]
# Convergence reached after 12500 samples!

# %%
gp_model_comp.null_model.plot_autocorrelation()
gp_model_comp.null_model.corner_plot_samples()

# %%
gp_model_comp.alt_model.plot_autocorrelation()
gp_model_comp.alt_model.corner_plot_samples()

# %% [markdown]
# # Generate lightcurves, and fit with both null and alternative models

# %%
gp_model_comp.process_lightcurves(nsims=100, fit=True, max_steps=1000, cores=cpus)

# %% [markdown]
# # Perform Likelihood Ratio Test

# %%
gp_model_comp.likelihood_ratio_test(path="LRT_no_period.png")
